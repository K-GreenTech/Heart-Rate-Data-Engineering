# %%
def clean_heartrate_data(data: list) -> tuple:
    """
    Clean raw heart-rate data by removing malformed or impossible values.
    to do this: loop over the data
    Then, "if" statements to check if piece of data is valid or not. if not valid, create a new list
    """
    cleaned_data = []
    
    for item in data:   
        if type(item) == str and item.isdigit():
            cleaned_data.append(int(item))
        if type(item) == int:
            cleaned_data.append(item) 

                
    return cleaned_data

def average(data: list) -> float:
    """
    Calculate average of a list of integers using a for-loop. Assumes data is clean.
    """
    total = 0
    numbers = data
    for num in data:
        total += num
    average = total / len(data)
    print("Average: ", average)

def median(data: list) -> float:
    new_filtered = clean_heartrate_data(data) 
    # returning length of list
    len_lst = len(new_filtered)
    # sorted list in ASC order
    sorted_HR_values = sorted(new_filtered)
    # apply calcs based on len_list
    # if len_list is even, then ....
    if len_lst % 2 == 0:
        # get two middle index_pos
        index_pos_2 = int(len_lst/2)
        index_pos_1 = index_pos_2 - 1
        # return and divide values of two middle index_pos to calc median
        median = (sorted_HR_values[index_pos_2] + sorted_HR_values[index_pos_1])/2
    # if len_list is odd, then ....
    else:
        # return index_pos of median (middle value) in list
        index_pos = (len_lst - 1 ) / 2
        for i,value in enumerate(sorted_HR_values):
            if i == index_pos:
                # if i == index_pos, then return median
                median = value
    return median
   
def range(data: list) -> float:
    clean_heartrate_data(data)
    
    x = max(data)
    y = min(data)

    difference = x - y
    return difference  
    
def rolling_avg(data: list, k: int) -> float:
    """
    CHALLENGE FUNCTION (Optional)
    commiting an average over a slidign window. First define window which is the len.. Then as looping thru list, size of the window stays the same. 
    value within the window is changing. length of data = the  
    """
    # window = len(data)

    # for 

    pass

def run(file: str):
    """
    Process heart rate data from the a file by cleaning and
    calculating summary statistics. Print out final values.

    Args:
        filename (str): The path to the data file (e.g., 'data/phase0.txt').

    Returns:
        float, float, float: You will return the average, median, and range.
    """
    data = []

    # open file using file I/O and read it into the `data` list
    file_object = open(file)

    # Do this: data = file_object.readlines() OR
 
    for line in file_object:
        #to check that the data get rid of \n character to have data by itself
        # print(line.strip())
        #then every data executes in for loop, we append it in a list
        data.append(line.strip()) 

    #print(data) #did this to test if it is doing what was supposed to do 

    # Use `clean_heartrate_data` to clean the data and remove invalid entries. 
    #do: this is tuple unpacking:
    cleaned_list = clean_heartrate_data(data)
        
    # calculate the average, median, and range of this file using the functions you've wrote
    avg = average(cleaned_list)
    med = median(cleaned_list)
    ran = range(cleaned_list)

    # print out your data quality measure to the console
    #print(file)
    #Not sure what to put here

    # print out your descriptive statistics to the console
    print("Average: ", avg)
    print("Median: ", med)
    print("Range: ", ran)

#calling the run function 4 different times with 3 different files while doing thru the run function
if __name__ == "__main__":
    run("data/phase0.txt")
    run("data/phase1.txt")
    run("data/phase2.txt")
    run("data/phase3.txt")
# Out:
# Average:  64.58730158730158
# Average:  None
# Median:  62
# Range:  39
# Average:  87.29629629629629
# Average:  None
# Median:  88.5
# Range:  54
# Average:  85.18333333333334
# Average:  None
# Median:  85.0
# Range:  63
# Average:  60.651162790697676
# Average:  None
# Median:  56.5
# Range:  49
